# %% [markdown]
# ### Lack of robustness of Markowitz analysis and Global Minimum Variance Portfolio

# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline
import risk_toolkit as rk
import numpy as np
import pandas as pd

# %%
ind = rk.get_ind_returns()

exp_return = rk.annualized_returns(ind['1996':'2000'], 12)

cov_matrix = ind['1996':'2000'].cov()

# %%
l = ['Food', 'Steel']

rk.max_sharpe_ratio(0.10, exp_return[l], cov_matrix.loc[l,l])
# Out:
# array([0.75040363, 0.24959637])

# %%
exp_return[l]
# Out:
# Food     0.116799
# Steel    0.115809
# dtype: float64

# %% [markdown]
# ### Let's build the naive diversification portfolio (equally-weighted)

# %%
rk.efficient_frontier_multi_asset(20, exp_return, cov_matrix, show_cml=True, risk_free_rate=0.1, show_ew=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %% [markdown]
# ### This estimates the GMV portfolio

# %%
rk.efficient_frontier_multi_asset(20, exp_return, cov_matrix, show_cml=True, risk_free_rate=0.1, show_ew=True, show_gmv=True)
# Out:
# <AxesSubplot:xlabel='Volatility'>
