# %%
# %load_ext autoreload
# %autoreload 2
# %reload_ext autoreload
# %matplotlib inline
import risk_toolkit as rk
import numpy as np
import pandas as pd
from scipy.optimize import minimize
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
ind = rk.get_ind_returns()

exp_return = rk.annualized_returns(ind['1996':'2000'], 12)

cov_matrix = ind['1996': '2000'].cov()

# %%
l = ['Games', 'Fin']

rk.efficient_frontier_2_asset(20, exp_return[l], cov_matrix.loc[l, l])
# Out:
# <AxesSubplot:xlabel='Volatility'>

# %%
w15 = rk.minimize_vol(0.15, exp_return[l], cov_matrix.loc[l, l])

# %%
vol15 = rk.portfolio_vol(w15, cov_matrix.loc[l, l])

# %%
vol15
# Out:
# 0.056163669406706564

# %%
l = ['Smoke', 'Fin', 'Games', 'Coal']

rk.efficient_frontier_multi_asset(25, exp_return[l], cov_matrix.loc[l, l])
# Out:
# <AxesSubplot:xlabel='Volatility'>
